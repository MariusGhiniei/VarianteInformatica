# %% [markdown]
# --VARIANTA 6--
# 16 + 30 + 6 + 10 = 46 + 16 = 62

# %% [markdown]
# -SUBIECTUL I- (16p)

# %%
1) a) x>=3 && y<=5 

2) f(2121, 19)
x = 2121
y = 19
1 + 1 + f(212, 1)
0 + 1 + f(21, 0)
1
a) 4 -4p

3) Alex - 1
Cezar - 2, 3,
Tudor - 2, 3,
Daria - 2, 3,
Ela - 2, 3,
Maria - 2, 3,

(Alex, Cezar, Daria)
(Alex, Daria, Cezar)
(Alex, Tudor, Daria)
(Alex, Daria, Tudor)
(Alex, Ela, Daria)
(Alex, Daria, Ela)
(Alex, Maria, Daria)
(Alex, Daria, Maria)
b) 8 -4p

4) d) (7, 4, 5, 0, 4, 5, 4) 0 e pe pozitia 4 deci 4 e radacina, 4 e pe pozitiile 2 si 5 deci 2 si 5 sunt fii lui 4, 5 e pe pozitiile 3 si 6 deci 3 si 6 sunt fii lui 5, 7 e pe pozitia 1 deci 1 e fiul lui 7.
-4p
5) c) 2 -4p

# %% [markdown]
# -SUBIECTUL II-

# %%
x = 404
y = 413
k = 0
i = 404
i <= y (404 <= 413)
{
    n = i = 404
    c = 0
    n > 0
    c = 0
    {
        n % 2 == 0
        n = 40
        n % 2 == 0
        n = 4
        n % 2 == 0
        c = 0 (cauta cifrele impare si nu mai repeta while-ul cand gaseste una)
    }
    k = k + c = 0 + 0 = 0
    i = i + 1 = 404 + 1 = 405
}
i <= y (405 <= 413)
{
    n = i = 405
    c = 0
    n > 0
    {
        n % 2 == 1
        c = 1
        n = 40
    }
    k = 0 + 1 = 1
    i = 405 + 1 = 406
    ...
    i = 407
    k = 2
    i = 409
    k = 3
    i = 410
    k = 4
    i = 411
    k = 5
    i = 412
    k = 6
    i = 413
    k = 7
    cout << 7; -6p
}

b) Daca pentru x se citeste valoarea 58, pentru y se pot citi valorile 61, respectiv 62, deoarece algoritmul numara cate numere contin o cifra impara de la x pana la y. Deci numerele vor fi 58, 59, 61.
-3p
c) #include <iostream>
using namespace std;

int main()
{
    int x, y, n, k, c, i;
    cin>>x>>y;
    k = 0;
    i = x;
    while(i<=y)
    {
        n = i;
        c = 0;
        while(n>0 && c==0)
        {
            if(n%2==1)
            {
            c = 1;
            }
            n = n / 10;
        }
        k = k + c;
        i = i + 1;
    }
    cout<<k;
}
-10p

d)
citeste x, y
k <- 0
pentru i <- x, y executa
{
    n <- i; c <- 0
    cat timp n>0 si c=0 executa
    {
    daca n%2=1 atunci c <- 1
    {
    }
    n <- [n/10]
    }
    k <- k + c
    i <- i + 1 (nu stiu sigur daca mai e necesara linia asta de cod deoarece e pseudocod de tip pentru ... executa) /// nu este necesara, dar e gresit sa o pui
}
scrie k
-5p

2) struct figura{
    int diametru;
    struct{
        int x;
        int y;
    }centru;
}c;
-6p

3) s = PRASLEA*CEL*VOINIC
s = 18
i = 0
...?

# %% [markdown]
# -SUBIECTUL III-

# %%
1) #include <iostream>
using namespace std;

int numar(int n, int c, void m)
{
	int j, oglm, cm;
	m = 0;
	oglm = 0;
	while(n!=0)
	{
		if(n%10 == 0 || n%10 == c)
		{
			n = n / 10;
		}
		else
		{
			m = m * 10 + n % 10;
			n = n / 10;
		}
	}
	while(m!=0)
	{
	    cm = m % 10;
	    oglm = oglm * 10 + cm;
	    m = m / 10;
	}
	return oglm;
} -6p
